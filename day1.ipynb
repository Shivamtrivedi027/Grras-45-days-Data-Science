# %%
# DAY 1

# #variable
# a=10;
# #variable declare
# print(a)
# #print variable in python

# a=20
# b=a
# a=30
# print(a,b)
# print(id(a), id(b))

# a=int(input("Enter the number: "))
# print(a)
# print(type(a))


# example
